# %%
# sqlite
import sqlite3
import pandas as pd

# %%
# connection
conn = sqlite3.connect("data\jupyterlitetest.sqlite")

# %%
# results into pandas df
df = pd.read_sql('select * from test_table', conn)
df
# Out:
#   code            description
# 0  AAA  this is the first row
# 1  AAB     and the second row

# %%
conn.close()
